# %%
# %ls
# Out:
# Untitled.ipynb  first.ipynb

# %%
conda install -c r r-essentials
ls
# Out:
#   File "<ipython-input-2-14cd2068d76d>", line 1
#     conda install -c r r-essentials
#                 ^
# SyntaxError: invalid syntax

# %%
import os
from IPython.display import display, Image
names = [f for f in os.listdir('/Users/sunlei/Documents/picture/beauty/') if f.endswith('.jpg')]
for name in names[:8]:
    display(Image('/Users/sunlei/Documents/picture/beauty/' + name, width=100))

# %%
import os
os.getcwd()
# Out:
# '/Users/sunlei/Documents/github/python'

# %%
# %pwd
# Out:
# u'/Users/sunlei/Documents/github/python'

# %%
os.mkdir('lala')

# %%
os.listdir('/Usr/')
# Out:
# ['bin', 'include', 'lib', 'libexec', 'local', 'sbin', 'share', 'standalone']

# %% [markdown]
# %ls

# %%
# %ls
# Out:
# first.ipynb            lala/                  second_os_magic.ipynb

# %%
os.rmdir('lala')

# %%
# %ls
# Out:
# first.ipynb            second_os_magic.ipynb

# %%
import markdown
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-26-3281bb546fc0> in <module>()
# ----> 1 import markdown
#
# ImportError: No module named markdown

# %%
import markdown

# %%
# %vi test
# Out:
# ERROR:root:Line magic function `%vi` not found.

# %% [markdown]
# os.mknod('test')

# %%
import sys
# sys.setdefaultencoding('utf8')
f = open('test','r+w')
print 'this is a test file'
# f = open(test,'w')
f.write('this is a test file')  
line = f.readline()
# print line
html = markdown.markdown(line)
print html
# Out:
# this is a test file
# <p>this is a test filethis is a test filethis is a test file</p>

# %%
f.close
# Out:
# <function close>

# %%
def txt2html(text):
    return markdown.markdown(text)

# %%
html = txt2html(line)
print html
# Out:
# <p>this is a test filethis is a test filethis is a test file</p>
